# %% [markdown]
# ## Backtesting Dual moving average strategy on multiple assets using vectorbt

# %% [markdown]
# Reference: # http://qubitquants.pro/multi_asset_portfolio_simulation/index.html

# %% [markdown]
# In this tutorial, we will talk about Multi Asset Portfolio Simulation, beginning with:
#
# Running Multi-asset Portfolio Backtesting simulation using vbt.Portfolio.from_signals() like:
# 1. Unified Portfolio Simulation
# 2. Asset-wise Discrete Portfolio Simulation
# 3. Grouped Portfolio Simulation

# %% [markdown]
# ## 1) Unified Portfolio Simulation

# %%
import vectorbt as vbt
import numpy
import pandas

import warnings

warnings.filterwarnings("ignore")

# %%
symbols = ["MSFT","AAPL","GOOGL"]
close_price = vbt.YFData.download(symbols, interval="1d",
                        missing_index="drop",
                        start="2020-01-01").get("Close")
print(close_price)
# Out:
# symbol                           MSFT        AAPL       GOOGL
# Date
# 2019-12-31 05:00:00+00:00  152.596542   71.711746   66.969498
# 2020-01-02 05:00:00+00:00  155.422028   73.347939   68.433998
# 2020-01-03 05:00:00+00:00  153.486755   72.634842   68.075996
# 2020-01-06 05:00:00+00:00  153.883514   73.213600   69.890503
# 2020-01-07 05:00:00+00:00  152.480469   72.869278   69.755501
# ...                               ...         ...         ...
# 2023-07-31 04:00:00+00:00  335.920013  196.449997  132.720001
# 2023-08-01 04:00:00+00:00  336.339996  195.610001  131.550003
# 2023-08-02 04:00:00+00:00  327.500000  192.580002  128.380005
# 2023-08-03 04:00:00+00:00  326.660004  191.169998  128.449997
# 2023-08-04 04:00:00+00:00  327.779999  181.990005  128.110001
#
# [905 rows x 3 columns]

# %%
"""
Setup entry and exit condition, which is with moving average (MA) 
crossover combination of fast MA of 9 days and slow MA of 17 days
"""

SMA_9 = vbt.MA.run(close_price, window=9)
SMA_17 = vbt.MA.run(close_price, window=17)

entries = SMA_9.ma_crossed_above(SMA_17)
exits = SMA_9.ma_crossed_below(SMA_17)

# %% [markdown]
# ##### Description of a few Parameter settings for vbt.Portfolio.from_signals()
#
# We will see a short description of the new parameters of vbt.Portfolio.from_signals()
#
# a.) `size` : Specifies the position size in units. For any fixed size, you can set to any number to buy/sell some fixed amount or value. For any target size, you can set to any number to buy/sell an amount relative to the current position or value. If you set this to np.nan or 0 it will get skipped (or close the current position in the case of setting 0 for any target size). Set to `np.inf` to buy for all cash, or `-np.inf` to sell for all free cash. A point to remember setting to `np.inf` may cause the scenario for the portfolio simulation to become heavily weighted to one single instrument. So use a sensible size related.
#
# b.) `size_type`: Choose units to be used for the `size`. In this tutorial, we use `percent` and for other parameter like `amount`, `value`, `TargetValue`,`TargetAmount`, please refer here: https://vectorbt.dev/api/portfolio/enums/#vectorbt.portfolio.enums.SizeType for more explanation.
#
# b.) `init_cash` : Initial capital per column (or per group with cash sharing). By setting it to auto the initial capital is automatically decided based on the position size you specify in the above size parameter.
#
# c.) `cash_sharing` : Accepts a boolean (`True` or `False`) value to specify whether cash sharing is to be disabled or if enabled then cash is shared across all the assets in the portfolio or cash is shared within the same group.
# If `group_by` is None and `cash_sharing` is True, group_by becomes True to form a single group with cash sharing. Example:
# Consider three columns (3 assets), each having $100 of starting capital. If we built one group of two columns and one group of one column, the `init_cash` would be np.array([200, 100]) with cash sharing enabled and np.array([100, 100, 100]) without cash sharing.
#
# d.) `call_seq` : Default sequence of calls per row and group. Controls the sequence in which order_func_nb is executed within each segment. For more details of this function kindly refer the documentation.
#
# e.) `group_by` : can be boolean, integer, string, or sequence to call multi-level indexing and can accept both level names and level positions. In this tutorial I will be setting group_by = True to treat the entire portfolio simulation in a unified manner for all assets in congruence with cash_sharing = True. When I want to create custom groups with specific symbols in each group then I will be setting group_by = 0 to specify the level position (in multi-index levels) as the first in the hierarchy.``

# %%
"""In this section, we run the portfolio simulation treating the entire portfolio as a singular asset by enabling the following parameters in the pf.from_signals():

cash_sharing = True
group_by = True
call_seq = "auto"
size = 1000
"""
unified_portfolio = vbt.Portfolio.from_signals(close_price, 
                           entries,
                           exits,
                           init_cash=100000, # in $
                           fees=0.0025, # in %
                           slippage=0.0025, # in %
                           freq="1D",
                           group_by=True,
                           cash_sharing=True,
                           call_seq="auto",
                           size_type="value",
                           size=10000) # 

unified_portfolio.stats()
# Out:
# Start                          2019-12-31 05:00:00+00:00
# End                            2023-08-04 04:00:00+00:00
# Period                                 905 days 00:00:00
# Start Value                                     100000.0
# End Value                                  114244.364701
# Total Return [%]                               14.244365
# Benchmark Return [%]                          119.959226
# Max Gross Exposure [%]                         37.042729
# Total Fees Paid                              3849.043574
# Max Drawdown [%]                                9.599634
# Max Drawdown Duration                  410 days 00:00:00
# Total Trades                                          77
# Total Closed Trades                                   75
# Total Open Trades                                      2
# Open Trade PnL                               2225.853808
# Win Rate [%]                                   41.333333
# Best Trade [%]                                 53.523216
# Worst Trade [%]                               -15.414574
# Avg Winning Trade [%]                          10.222951
# Avg Losing Trade [%]                           -4.477866
# Avg Winning Trade Duration    32 days 02:19:21.290322580
# Avg Losing Trade Duration               10 days 18:00:00
# Profit Factor                                   1.608475
# Expectancy                                    160.246812
# Sharpe Ratio                                    0.832017
# Calmar Ratio                                     0.57479
# Omega Ratio                                     1.158445
# Sortino Ratio                                   1.223772
# Name: group, dtype: object

# %%
unified_portfolio.plot(group_by=True, subplots=["cum_returns","cash","value"]).show()

# %% [markdown]
# ### Asset-wise Discrete Portfolio Simulation
#
# In this section, we will see how to run the portfolio simulation for each asset in the portfolio independently.

# %%
discrete_portfolio = vbt.Portfolio.from_signals(close_price, 
                           entries,
                           exits,
                           init_cash=100000, # in $
                           fees=0.0025, # in %
                           slippage=0.0025, # in %
                           freq="1D",
                           group_by=False,
                           call_seq="auto",
                           size_type="value",
                           size=10000) # For each trades, limit the position size in $

# %%
# trade each assets with start value of 100,000 and apply the trading strategy respectively to see which compa

stats_df = pandas.concat([unified_portfolio.stats()] + 
                         [discrete_portfolio[symbol].stats() for symbol 
                          in discrete_portfolio.wrapper.columns], axis = 1)
stats_df.rename(inplace = True, columns = {'group':'unified portfolio'})  
stats_df
# Out:
#                                      unified portfolio  \
# Start                        2019-12-31 05:00:00+00:00
# End                          2023-08-04 04:00:00+00:00
# Period                               905 days 00:00:00
# Start Value                                   100000.0
# End Value                                114244.364701
# Total Return [%]                             14.244365
# Benchmark Return [%]                        119.959226
# Max Gross Exposure [%]                       37.042729
# Total Fees Paid                            3849.043574
# Max Drawdown [%]                              9.599634
# Max Drawdown Duration                410 days 00:00:00
# Total Trades                                        77
# Total Closed Trades                                 75
# Total Open Trades                                    2
# Open Trade PnL                             2225.853808
# Win Rate [%]                                 41.333333
# Best Trade [%]                               53.523216
# Worst Trade [%]                             -15.414574
# Avg Winning Trade [%]                        10.222951
# Avg Losing Trade [%]                         -4.477866
# Avg Winning Trade Duration  32 days 02:19:21.290322580
# Avg Losing Trade Duration             10 days 18:00:00
# Profit Factor                                 1.608475
# Expectancy                                  160.246812
# Sharpe Ratio                                  0.832017
# Calmar Ratio                                   0.57479
# Omega Ratio                                   1.158445
# Sortino Ratio                                 1.223772
#
#                                          (9, 17, MSFT)  \
# Start                        2019-12-31 05:00:00+00:00
# End                          2023-08-04 04:00:00+00:00
# Period                               905 days 00:00:00
# Start Value                                   100000.0
# End Value                                100464.283108
# Total Return [%]                              0.464283
# Benchmark Return [%]                        114.801721
# Max Gross Exposure [%]                       13.156695
# Total Fees Paid                            1408.181161
# Max Drawdown [%]                              5.323673
# Max Drawdown Duration                427 days 00:00:00
# Total Trades                                        28
# Total Closed Trades                                 28
# Total Open Trades                                    0
# Open Trade PnL                                     0.0
# Win Rate [%]                                 39.285714
# Best Trade [%]                               27.570603
# Worst Trade [%]                             -15.414574
# Avg Winning Trade [%]                         7.222849
# Avg Losing Trade [%]                         -4.401182
# Avg Winning Trade Duration  32 days 02:10:54.545454545
# Avg Losing Trade Duration   10 days 05:38:49.411764705
# Profit Factor                                 1.061899
# Expectancy                                    16.58154
# Sharpe Ratio                                  0.083772
# Calmar Ratio                                  0.035125
# Omega Ratio                                   1.015515
# Sortino Ratio                                 0.117408
#
#                                          (9, 17, AAPL)  \
# Start                        2019-12-31 05:00:00+00:00
# End                          2023-08-04 04:00:00+00:00
# Period                               905 days 00:00:00
# Start Value                                   100000.0
# End Value                                109144.815476
# Total Return [%]                              9.144815
# Benchmark Return [%]                        153.779911
# Max Gross Exposure [%]                        15.37407
# Total Fees Paid                            1098.078487
# Max Drawdown [%]                              2.423971
# Max Drawdown Duration                319 days 00:00:00
# Total Trades                                        22
# Total Closed Trades                                 21
# Total Open Trades                                    1
# Open Trade PnL                             2061.436761
# Win Rate [%]                                 42.857143
# Best Trade [%]                               53.523216
# Worst Trade [%]                              -9.613306
# Avg Winning Trade [%]                        13.122515
# Avg Losing Trade [%]                         -3.953791
# Avg Winning Trade Duration  36 days 21:19:59.999999999
# Avg Losing Trade Duration              8 days 22:00:00
# Profit Factor                                 2.489228
# Expectancy                                  337.303748
# Sharpe Ratio                                  1.274723
# Calmar Ratio                                  1.481964
# Omega Ratio                                   1.263997
# Sortino Ratio                                 1.947054
#
#                                         (9, 17, GOOGL)
# Start                        2019-12-31 05:00:00+00:00
# End                          2023-08-04 04:00:00+00:00
# Period                               905 days 00:00:00
# Start Value                                   100000.0
# End Value                                104635.266117
# Total Return [%]                              4.635266
# Benchmark Return [%]                         91.296045
# Max Gross Exposure [%]                        13.08177
# Total Fees Paid                            1342.783926
# Max Drawdown [%]                              4.499051
# Max Drawdown Duration                428 days 00:00:00
# Total Trades                                        27
# Total Closed Trades                                 26
# Total Open Trades                                    1
# Open Trade PnL                              164.417047
# Win Rate [%]                                 42.307692
# Best Trade [%]                               31.516836
# Worst Trade [%]                               -9.47488
# Avg Winning Trade [%]                        10.850683
# Avg Losing Trade [%]                         -4.984034
# Avg Winning Trade Duration  28 days 04:21:49.090909091
# Avg Losing Trade Duration             12 days 19:12:00
# Profit Factor                                 1.596531
# Expectancy                                  171.955733
# Sharpe Ratio                                  0.628242
# Calmar Ratio                                  0.409917
# Omega Ratio                                   1.129641
# Sortino Ratio                                 0.939655

# %% [markdown]
# -------------------------------------------------

# %% [markdown]
# #### (Optional) Additional work - just to check trading orders & PnL of AAPL

# %%
discrete_portfolio[(9, 17, "AAPL")].plots()
# Out:
# FigureWidget({
#     'data': [{'legendgroup': '0',
#               'line': {'color': '#1f77b4'},
#               'name': 'Close',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '763a8af2-715d-4398-88a4-5ee2c8dc139b',
#               'x': array([datetime.datetime(2019, 12, 31, 5, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2020, 1, 2, 5, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2020, 1, 3, 5, 0, tzinfo=datetime.timezone.utc), ...,
#                           datetime.datetime(2023, 8, 2, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 8, 3, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 8, 4, 4, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x',
#               'y': array([ 71.71174622,  73.34793854,  72.63484192, ..., 192.58000183,
#                           191.16999817, 181.99000549]),
#               'yaxis': 'y'},
#              {'customdata': array([[ 56.        , 169.22130082,  25.0625    ],
#                                    [ 58.        ,  93.49725027,  25.0625    ],
#                                    [ 60.        ,  89.95775955,  25.0625    ],
#                                    [ 62.        ,  85.1397955 ,  25.0625    ],
#                                    [ 64.        ,  83.02261294,  25.0625    ],
#                                    [ 66.        ,  71.01535289,  25.0625    ],
#                                    [ 68.        ,  84.46012779,  25.0625    ],
#                                    [ 70.        ,  79.23666519,  25.0625    ],
#                                    [ 72.        ,  80.89865948,  25.0625    ],
#                                    [ 74.        ,  80.36528337,  25.0625    ],
#                                    [ 76.        ,  77.53821836,  25.0625    ],
#                                    [ 78.        ,  69.38220973,  25.0625    ],
#                                    [ 80.        ,  67.84908383,  25.0625    ],
#                                    [ 82.        ,  68.93244639,  25.0625    ],
#                                    [ 84.        ,  58.44011894,  25.0625    ],
#                                    [ 86.        ,  57.87609838,  25.0625    ],
#                                    [ 88.        ,  69.19599044,  25.0625    ],
#                                    [ 90.        ,  72.4085008 ,  25.0625    ],
#                                    [ 92.        ,  67.21818895,  25.0625    ],
#                                    [ 94.        ,  66.29071314,  25.0625    ],
#                                    [ 96.        ,  73.77608818,  25.0625    ],
#                                    [ 98.        ,  66.55035384,  25.0625    ]]),
#               'hovertemplate': ('Order Id: %{customdata[0]}<br>' ... '<br>Fees: %{customdata[2]:.6f}'),
#               'legendgroup': '1',
#               'marker': {'color': '#37B13F',
#                          'line': {'color': 'rgb(38,123,44)', 'width': 1},
#                          'size': 8,
#                          'symbol': 'triangle-up'},
#               'mode': 'markers',
#               'name': 'Buy',
#               'type': 'scatter',
#               'uid': 'c8d13364-ab5d-41b8-8f72-ebb004c5f5cd',
#               'x': array([datetime.datetime(2020, 4, 3, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2020, 8, 3, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2020, 10, 2, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2020, 11, 12, 5, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2020, 12, 4, 5, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2021, 1, 25, 5, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2021, 3, 19, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2021, 4, 7, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2021, 6, 2, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2021, 6, 4, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2021, 6, 14, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2021, 8, 10, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2021, 8, 12, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2021, 10, 18, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2022, 2, 4, 5, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2022, 3, 24, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2022, 6, 3, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2022, 7, 1, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2022, 10, 24, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2022, 11, 18, 5, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 1, 17, 5, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 3, 13, 4, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x',
#               'y': array([ 59.24195093, 107.22240463, 111.44119251, 117.74752266, 120.75023472,
#                           141.16665752, 118.69506077, 126.51971125, 123.92047117, 124.74291859,
#                           129.29108009, 144.48948856, 147.75439011, 145.43223873, 171.54311424,
#                           173.21485519, 144.87833668, 138.45059475, 149.14117973, 151.22781948,
#                           135.88413601, 150.63781666]),
#               'yaxis': 'y'},
#              {'customdata': array([[ 57.        , 169.22130082,  38.63600219],
#                                    [ 59.        ,  93.49725027,  25.68478317],
#                                    [ 61.        ,  89.95775955,  25.72741717],
#                                    [ 63.        ,  85.1397955 ,  24.38942114],
#                                    [ 65.        ,  83.02261294,  26.27362192],
#                                    [ 67.        ,  71.01535289,  23.76726441],
#                                    [ 69.        ,  84.46012779,  24.91879382],
#                                    [ 71.        ,  79.23666519,  25.84219203],
#                                    [ 73.        ,  80.89865948,  24.63440823],
#                                    [ 75.        ,  80.36528337,  24.9394816 ],
#                                    [ 77.        ,  77.53821836,  28.10629315],
#                                    [ 79.        ,  69.38220973,  24.982028  ],
#                                    [ 81.        ,  67.84908383,  24.46350315],
#                                    [ 83.        ,  68.93244639,  29.91243902],
#                                    [ 85.        ,  58.44011894,  23.77011638],
#                                    [ 87.        ,  57.87609838,  24.01919614],
#                                    [ 89.        ,  69.19599044,  22.7727533 ],
#                                    [ 91.        ,  72.4085008 ,  29.00744562],
#                                    [ 93.        ,  67.21818895,  23.31583924],
#                                    [ 95.        ,  66.29071314,  24.36388572],
#                                    [ 97.        ,  73.77608818,  27.17660135]]),
#               'hovertemplate': ('Order Id: %{customdata[0]}<br>' ... '<br>Fees: %{customdata[2]:.6f}'),
#               'legendgroup': '2',
#               'marker': {'color': '#EA4335',
#                          'line': {'color': 'rgb(181,31,18)', 'width': 1},
#                          'size': 8,
#                          'symbol': 'triangle-down'},
#               'mode': 'markers',
#               'name': 'Sell',
#               'type': 'scatter',
#               'uid': '7a5206e8-e04e-46a9-9308-1a3f2922c1d9',
#               'x': array([datetime.datetime(2020, 7, 28, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2020, 9, 11, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2020, 10, 27, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2020, 11, 27, 5, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2021, 1, 12, 5, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2021, 2, 9, 5, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2021, 3, 30, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2021, 5, 3, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2021, 6, 3, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2021, 6, 7, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2021, 8, 5, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2021, 8, 11, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2021, 9, 17, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2022, 1, 12, 5, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2022, 2, 22, 5, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2022, 4, 12, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2022, 6, 14, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2022, 8, 29, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2022, 11, 8, 5, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2022, 12, 2, 5, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 2, 27, 5, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x',
#               'y': array([ 91.32656942, 109.88465693, 114.39776756, 114.58529348, 126.58537708,
#                           133.87113316, 118.01447371, 130.45572762, 121.80378954, 124.13062237,
#                           144.99323685, 144.02555408, 144.22304192, 173.57538048, 162.69724846,
#                           166.00425259, 131.64203968, 160.24331566, 138.74720284, 147.01236156,
#                           147.34639378]),
#               'yaxis': 'y'},
#              {'customdata': array([[0.00000000e+00, 0.00000000e+00, 5.36570238e+03, 5.35232157e-01],
#                                    [1.00000000e+00, 1.00000000e+00, 1.98165986e+02, 1.97671806e-02],
#                                    [2.00000000e+00, 2.00000000e+00, 2.15176950e+02, 2.14640349e-02],
#                                    [4.00000000e+00, 4.00000000e+00, 4.33112644e+02, 4.32032563e-02],
#                                    [7.00000000e+00, 7.00000000e+00, 2.60972119e+02, 2.60321316e-02],
#                                    [1.00000000e+01, 1.00000000e+01, 1.16434847e+03, 1.16144485e-01],
#                                    [1.30000000e+01, 1.30000000e+01, 1.88500067e+03, 1.88029992e-01],
#                                    [1.70000000e+01, 1.70000000e+01, 1.52390830e+03, 1.52010803e-01],
#                                    [2.00000000e+01, 2.00000000e+01, 7.93401438e+02, 7.91422881e-02]]),
#               'hovertemplate': ('Exit Trade Id: %{customdata[0]' ... 'r>Return: %{customdata[3]:.2%}'),
#               'legendgroup': '3',
#               'marker': {'color': '#37B13F',
#                          'line': {'color': 'rgb(38,123,44)', 'width': 1},
#                          'opacity': array([0.9       , 0.75329138, 0.75377433, 0.75996162, 0.75507447, 0.78072172,
#                                            0.80118135, 0.79092978, 0.77019037]),
#                          'size': array([14.        ,  7.15359768,  7.17613529,  7.46487548,  7.23680872,
#                                          8.43368039,  9.3884632 ,  8.91005658,  7.94221746]),
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Closed - Profit',
#               'type': 'scatter',
#               'uid': 'a997f56e-d91a-47e6-813b-ada3524f4801',
#               'x': array([datetime.datetime(2020, 7, 28, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2020, 9, 11, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2020, 10, 27, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2021, 1, 12, 5, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2021, 5, 3, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2021, 8, 5, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2022, 1, 12, 5, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2022, 8, 29, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 2, 27, 5, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x2',
#               'y': array([0.53523216, 0.01976718, 0.02146403, 0.04320326, 0.02603213, 0.11614449,
#                           0.18802999, 0.1520108 , 0.07914229]),
#               'yaxis': 'y2'},
#              {'customdata': array([[ 3.00000000e+00,  3.00000000e+00, -3.18683466e+02, -3.17888745e-02],
#                                    [ 5.00000000e+00,  5.00000000e+00, -5.66924002e+02, -5.65510226e-02],
#                                    [ 6.00000000e+00,  6.00000000e+00, -1.07463764e+02, -1.07195775e-02],
#                                    [ 8.00000000e+00,  8.00000000e+00, -2.20933615e+02, -2.20382658e-02],
#                                    [ 9.00000000e+00,  9.00000000e+00, -9.92093407e+01, -9.89619359e-03],
#                                    [ 1.10000000e+01,  1.10000000e+01, -8.22333273e+01, -8.20282567e-03],
#                                    [ 1.20000000e+01,  1.20000000e+01, -2.89124743e+02, -2.88403733e-02],
#                                    [ 1.40000000e+01,  1.40000000e+01, -5.65786065e+02, -5.64375127e-02],
#                                    [ 1.50000000e+01,  1.50000000e+01, -4.66403242e+02, -4.65240142e-02],
#                                    [ 1.60000000e+01,  1.60000000e+01, -9.63733934e+02, -9.61330607e-02],
#                                    [ 1.80000000e+01,  1.80000000e+01, -7.47042642e+02, -7.45179693e-02],
#                                    [ 1.90000000e+01,  1.90000000e+01, -3.28872097e+02, -3.28051967e-02]]),
#               'hovertemplate': ('Exit Trade Id: %{customdata[0]' ... 'r>Return: %{customdata[3]:.2%}'),
#               'legendgroup': '4',
#               'marker': {'color': '#EA4335',
#                          'line': {'color': 'rgb(181,31,18)', 'width': 1},
#                          'opacity': array([0.75671292, 0.76376058, 0.7507163 , 0.75393776, 0.75048196, 0.75      ,
#                                            0.75587374, 0.76372827, 0.76090675, 0.77502619, 0.76887423, 0.75700218]),
#                          'size': array([7.31326974, 7.64216042, 7.03342748, 7.18376222, 7.0224913 , 7.        ,
#                                         7.27410777, 7.64065279, 7.50898177, 8.16788878, 7.88079729, 7.32676853]),
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Closed - Loss',
#               'type': 'scatter',
#               'uid': '5bb879e9-15a2-4040-ac6a-49fb352552c5',
#               'x': array([datetime.datetime(2020, 11, 27, 5, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2021, 2, 9, 5, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2021, 3, 30, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2021, 6, 3, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2021, 6, 7, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2021, 8, 11, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2021, 9, 17, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2022, 2, 22, 5, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2022, 4, 12, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2022, 6, 14, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2022, 11, 8, 5, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2022, 12, 2, 5, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x2',
#               'y': array([-0.03178887, -0.05655102, -0.01071958, -0.02203827, -0.00989619,
#                           -0.00820283, -0.02884037, -0.05643751, -0.04652401, -0.09613306,
#                           -0.07451797, -0.0328052 ]),
#               'yaxis': 'y2'},
#              {'customdata': array([[2.10000000e+01, 2.10000000e+01, 2.06143676e+03, 2.05629602e-01]]),
#               'hovertemplate': ('Exit Trade Id: %{customdata[0]' ... 'r>Return: %{customdata[3]:.2%}'),
#               'legendgroup': '5',
#               'marker': {'color': '#FFAA00',
#                          'line': {'color': 'rgb(178,118,0)', 'width': 1},
#                          'opacity': array([0.80619045]),
#                          'size': array([9.6222211]),
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Open',
#               'type': 'scatter',
#               'uid': '5ec83601-c12e-414e-85ee-ecf41a73f115',
#               'x': array([datetime.datetime(2023, 8, 4, 4, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x2',
#               'y': array([0.2056296]),
#               'yaxis': 'y2'},
#              {'legendgroup': '6',
#               'line': {'color': '#7f7f7f'},
#               'name': 'Benchmark',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '61e02af3-9674-4333-88f9-5c6cd933ebd1',
#               'x': array([datetime.datetime(2019, 12, 31, 5, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2020, 1, 2, 5, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2020, 1, 3, 5, 0, tzinfo=datetime.timezone.utc), ...,
#                           datetime.datetime(2023, 8, 2, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 8, 3, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 8, 4, 4, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x3',
#               'y': array([1.        , 1.02281624, 1.01287231, ..., 2.68547361, 2.66581151,
#                           2.53779911]),
#               'yaxis': 'y3'},
#              {'hoverinfo': 'skip',
#               'legendgroup': '7',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '16a4e5e3-7868-4907-a701-b75b3dbecf07',
#               'x': array([datetime.datetime(2019, 12, 31, 5, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2020, 1, 2, 5, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2020, 1, 3, 5, 0, tzinfo=datetime.timezone.utc), ...,
#                           datetime.datetime(2023, 8, 2, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 8, 3, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 8, 4, 4, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x3',
#               'y': array([1, 1, 1, ..., 1, 1, 1]),
#               'yaxis': 'y3'},
#              {'connectgaps': False,
#               'fill': 'tonexty',
#               'fillcolor': 'rgba(0, 128, 0, 0.3)',
#               'hoverinfo': 'skip',
#               'legendgroup': '7',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'f1df2d71-545c-46f4-9ecb-2f01fdbed55c',
#               'x': array([datetime.datetime(2019, 12, 31, 5, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2020, 1, 2, 5, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2020, 1, 3, 5, 0, tzinfo=datetime.timezone.utc), ...,
#                           datetime.datetime(2023, 8, 2, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 8, 3, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 8, 4, 4, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x3',
#               'y': array([1.        , 1.        , 1.        , ..., 1.09849583, 1.09755747,
#                           1.09144815]),
#               'yaxis': 'y3'},
#              {'hoverinfo': 'skip',
#               'legendgroup': '7',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '3f89397d-458e-46ee-864a-2c0fa1aff1ea',
#               'x': array([datetime.datetime(2019, 12, 31, 5, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2020, 1, 2, 5, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2020, 1, 3, 5, 0, tzinfo=datetime.timezone.utc), ...,
#                           datetime.datetime(2023, 8, 2, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 8, 3, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 8, 4, 4, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x3',
#               'y': array([1, 1, 1, ..., 1, 1, 1]),
#               'yaxis': 'y3'},
#              {'connectgaps': False,
#               'fill': 'tonexty',
#               'fillcolor': 'rgba(255, 0, 0, 0.3)',
#               'hoverinfo': 'skip',
#               'legendgroup': '7',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'a4830e52-97e8-4ad4-91ad-69b0ecaefceb',
#               'x': array([datetime.datetime(2019, 12, 31, 5, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2020, 1, 2, 5, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2020, 1, 3, 5, 0, tzinfo=datetime.timezone.utc), ...,
#                           datetime.datetime(2023, 8, 2, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 8, 3, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 8, 4, 4, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x3',
#               'y': array([1., 1., 1., ..., 1., 1., 1.]),
#               'yaxis': 'y3'},
#              {'legendgroup': '8',
#               'line': {'color': '#9467bd'},
#               'name': 'Value',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'b6f3af8c-838d-440b-97f9-d1015ae1238d',
#               'x': array([datetime.datetime(2019, 12, 31, 5, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2020, 1, 2, 5, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2020, 1, 3, 5, 0, tzinfo=datetime.timezone.utc), ...,
#                           datetime.datetime(2023, 8, 2, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 8, 3, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 8, 4, 4, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x3',
#               'y': array([1.        , 1.        , 1.        , ..., 1.09849583, 1.09755747,
#                           1.09144815]),
#               'yaxis': 'y3'},
#              {'hoverinfo': 'skip',
#               'legendgroup': '7',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0.0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'ec32e9db-6d79-4d37-aab1-63286aac7f93',
#               'x': array([datetime.datetime(2019, 12, 31, 5, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2020, 1, 2, 5, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2020, 1, 3, 5, 0, tzinfo=datetime.timezone.utc), ...,
#                           datetime.datetime(2023, 8, 2, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 8, 3, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 8, 4, 4, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x3',
#               'y': array([1, 1, 1, ..., 1, 1, 1]),
#               'yaxis': 'y3'}],
#     'layout': {'annotations': [{'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Orders',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Trade PnL',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 0.6527777777777777,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Cumulative Returns',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 0.3055555555555555,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'}],
#                'height': 960,
#                'legend': {'orientation': 'h',
#                           'traceorder': 'normal',
#                           'x': 1,
#                           'xanchor': 'right',
#                           'y': 1.0416666666666667,
#                           'yanchor': 'bottom'},
#                'margin': {'b': 30, 'l': 30, 'r': 30, 't': 30},
#                'shapes': [{'line': {'color': 'gray', 'dash': 'dash'},
#                            'type': 'line',
#                            'x0': 0.0,
#                            'x1': 1.0,
#                            'xref': 'paper',
#                            'y0': 0,
#                            'y1': 0,
#                            'yref': 'y2'},
#                           {'line': {'color': 'gray', 'dash': 'dash'},
#                            'type': 'line',
#                            'x0': 0.0,
#                            'x1': 1.0,
#                            'xref': 'paper',
#                            'y0': 1,
#                            'y1': 1,
#                            'yref': 'y3'}],
#                'showlegend': True,
#                'template': '...',
#                'width': 750,
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'matches': 'x3', 'showticklabels': False},
#                'xaxis2': {'anchor': 'y2', 'domain': [0.0, 1.0], 'matches': 'x3', 'showticklabels': False},
#                'xaxis3': {'anchor': 'y3', 'domain': [0.0, 1.0], 'title': {'text': 'Index'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.6944444444444444, 1.0], 'title': {'text': 'Price'}},
#                'yaxis2': {'anchor': 'x2',
#                           'domain': [0.3472222222222222, 0.6527777777777777],
#                           'tickformat': '.2%',
#                           'title': {'text': 'Trade PnL'}},
#                'yaxis3': {'anchor': 'x3', 'domain': [0.0, 0.3055555555555555], 'title': {'text': 'Cumulative returns'}}}
# })
