# %% [markdown]
# Reference: http://qubitquants.pro/vbt_plot_strategy/index.html

# %%
import vectorbt as vbt

# %%
h1_df = vbt.YFData.download("BTC-USD", interval="1h", start="2023-06-01").get()
h4_df = h1_df.resample("4h").last()
h4_df.head()
# Out:
#                                    Open          High           Low  \
# Datetime
# 2023-05-31 16:00:00+00:00  27045.298828  27110.082031  27008.710938
# 2023-05-31 20:00:00+00:00  27185.619141  27290.621094  27169.482422
# 2023-06-01 00:00:00+00:00  26723.964844  26833.740234  26671.720703
# 2023-06-01 04:00:00+00:00  26788.693359  26857.482422  26769.904297
# 2023-06-01 08:00:00+00:00  26866.269531  26896.208984  26852.541016
#
#                                   Close     Volume  Dividends  Stock Splits
# Datetime
# 2023-05-31 16:00:00+00:00  27069.304688          0        0.0           0.0
# 2023-05-31 20:00:00+00:00  27216.927734  187372544        0.0           0.0
# 2023-06-01 00:00:00+00:00  26783.527344  611658752        0.0           0.0
# 2023-06-01 04:00:00+00:00  26806.955078          0        0.0           0.0
# 2023-06-01 08:00:00+00:00  26886.113281          0        0.0           0.0

# %%
kwargs1 = {"title_text" : "OHLCV Plot", "title_font_size" : 18}
h4_ohlc_sample = h4_df[["Open", "High", "Low", "Close"]].iloc[100:200]#.dropna()
f = h4_ohlc_sample.vbt.ohlcv.plot(**kwargs1)
f.show()
