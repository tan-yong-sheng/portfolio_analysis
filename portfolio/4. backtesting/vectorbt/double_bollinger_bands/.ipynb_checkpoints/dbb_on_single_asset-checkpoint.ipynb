# %% [markdown]
# ## Vectorbt - Dual Bollinger Bands on single asset

# %% [markdown]
# Reference 1: https://greyhoundanalytics.com/blog/create-a-custom-indicator-in-vectorbt/
#
# Reference 2: http://qubitquants.pro/strategydev/index.html

# %%
import vectorbt as vbt
import numpy
import os

# %%
cols = ['Open', 'High', 'Low', 'Close', 'Volume']
ohlcv = vbt.YFData.download("BTC-USD", missing_index="drop",
                            start="2023-06-12",
                            end="2023-08-10",
                            interval="5m").get(cols)
print(ohlcv)
# Out:
#                                    Open          High           Low  \
# Datetime
# 2023-06-11 16:00:00+00:00  25766.884766  25770.654297  25753.326172
# 2023-06-11 16:05:00+00:00  25772.251953  25799.263672  25772.251953
# 2023-06-11 16:10:00+00:00  25779.867188  25798.175781  25778.566406
# 2023-06-11 16:15:00+00:00  25789.996094  25817.318359  25789.996094
# 2023-06-11 16:20:00+00:00  25836.552734  25856.642578  25827.003906
# ...                                 ...           ...           ...
# 2023-08-10 14:25:00+00:00  29596.380859  29596.380859  29568.669922
# 2023-08-10 14:30:00+00:00  29575.099609  29581.851562  29568.730469
# 2023-08-10 14:35:00+00:00  29565.052734  29565.052734  29506.037109
# 2023-08-10 14:40:00+00:00  29496.574219  29496.574219  29416.005859
# 2023-08-10 14:45:00+00:00  29400.966797  29412.580078  29400.966797
#
#                                   Close     Volume
# Datetime
# 2023-06-11 16:00:00+00:00  25770.654297          0
# 2023-06-11 16:05:00+00:00  25789.410156          0
# 2023-06-11 16:10:00+00:00  25778.566406    5394432
# 2023-06-11 16:15:00+00:00  25817.318359          0
# 2023-06-11 16:20:00+00:00  25856.642578   29581312
# ...                                 ...        ...
# 2023-08-10 14:25:00+00:00  29573.675781   35317760
# 2023-08-10 14:30:00+00:00  29568.730469    7192576
# 2023-08-10 14:35:00+00:00  29518.011719    8366080
# 2023-08-10 14:40:00+00:00  29416.005859  118566912
# 2023-08-10 14:45:00+00:00  29412.580078    7769088
#
# [17261 rows x 5 columns]

# %%
m15_data = ohlcv.resample("15T").last()
h4_data = ohlcv.resample("4h").last()

# %%
h4_BBANDS = vbt.BBANDS.run(h4_data.Close)
m15_BBANDS = vbt.BBANDS.run(m15_data.Close)
m15_RSI = vbt.RSI.run(m15_data.Close) # 15 * 1min = 15 min RSI
m15_BBANDS_RSI = vbt.BBANDS.run(m15_RSI.rsi)

# %% [markdown]
# ##### Trading Rules:
#
# entry:
# 1. H4 "Low" price goes below its lower Bollinger band
# 2. 15m RSI goes below its lower Bollinger band
#
# exit:
# 1. H4 "High" price breaks its upper Bollinger band
# 2. 15m RSI breaks above its upper Bollinger band

# %%
## The two variables `bb_upper_fract` and `bb_lower_fract` are simply some adjustment 
# parameters for the RSI bollinger bands and they are explained at the end of this article.
bb_upper_fract = 0.99
bb_lower_fract = 1.01

entries = h4_BBANDS.lower_above(h4_data.Low)\
               & m15_RSI.rsi_below(bb_upper_fract * m15_BBANDS_RSI.lower)
exits = h4_BBANDS.upper_below(h4_data.High)\
                    & m15_RSI.rsi_above(bb_lower_fract * m15_BBANDS_RSI.lower)

# %%
entries.sum()
# Out:
# 1

# %%
exits.sum()
# Out:
# 28

# %%
pf = vbt.Portfolio.from_signals(m15_data.Close,
                      entries,
                      exits,
                      direction="LongOnly",
                      init_cash=1000)

# %%
pf.stats()
# Out:
# Start                         2023-06-11 16:00:00+00:00
# End                           2023-08-10 14:45:00+00:00
# Period                                 59 days 23:00:00
# Start Value                                      1000.0
# End Value                                   1047.503152
# Total Return [%]                               4.750315
# Benchmark Return [%]                          14.097036
# Max Gross Exposure [%]                            100.0
# Total Fees Paid                                     0.0
# Max Drawdown [%]                               2.858564
# Max Drawdown Duration                  51 days 20:45:00
# Total Trades                                          1
# Total Closed Trades                                   1
# Total Open Trades                                     0
# Open Trade PnL                                      0.0
# Win Rate [%]                                      100.0
# Best Trade [%]                                 4.750315
# Worst Trade [%]                                4.750315
# Avg Winning Trade [%]                          4.750315
# Avg Losing Trade [%]                                NaN
# Avg Winning Trade Duration              5 days 00:00:00
# Avg Losing Trade Duration                           NaT
# Profit Factor                                       inf
# Expectancy                                    47.503152
# Sharpe Ratio                                   2.738695
# Calmar Ratio                                  11.420705
# Omega Ratio                                    1.187133
# Sortino Ratio                                  4.103349
# dtype: object

# %%
pf.plot().show_svg()
